# %% [markdown]
# #Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
from scipy.special import i0

# %% [markdown]
# #Section 1

# %%
# Out:
# Hamming FIR coefficients (first 10):
# [-2.38303827e-04  2.80704990e-19  2.36355763e-04  3.95622521e-04
#   4.15254413e-04  2.64632041e-04 -3.47033517e-05 -3.98011539e-04
#  -6.87165663e-04 -7.47959484e-04]
#
# Kaiser (beta=5.0) FIR coefficients (first 10):
# [-1.09354326e-04  1.60894676e-19  1.61174123e-04  3.08276419e-04
#   3.57740946e-04  2.45461584e-04 -3.39437704e-05 -4.03997059e-04
#  -7.15133302e-04 -7.90945383e-04]
#
# Blackman FIR coefficients (first 10):
# [ 4.13391242e-20  1.23447048e-21  4.03963864e-06  1.45349064e-05
#   2.55564861e-05  2.37312867e-05 -4.14985043e-06 -5.97450100e-05
#  -1.24046188e-04 -1.57369760e-04]

# %% [markdown]
# #Section 2

# %%
# Out:
# Sampling frequency: fs = 44100 Hz
# Desired stopband attenuation: A_desired = 60.0 dB
# Transition bandwidth: delta_f = 500 Hz
# delta_omega (0->π) = 0.0712 rad
# Hamming: M ~ 47 taps
# Blackman: M ~ 78 taps
# Kaiser:   M ~ 321 taps, beta ~ 5.65
# delta_omega (0->2π) = 0.1425 rad
# Hamming (0->2π): M ~ 47
# Blackman (0->2π): M ~ 78
# Kaiser (0->2π):   M ~ 321, beta ~ 5.65

# %% [markdown]
# #Section 3

# %%
# Out:
# <ipython-input-33-9e2e4fcfe84a>:42: UserWarning: The filter's denominator is extremely small at frequencies [3.142],             around which a singularity may be present
#   w_gd_blk, gd_blk = signal.group_delay((h_blackman, 1), w=w_rad)

# %% [markdown]
# #Section 4

# %% [markdown]
# #Section 5

# %%
# Out:
# Performance Comparison Table:
#                                Metric     Hamming      Kaiser    Blackman
# 0                    SNR (Passband 1)  186.868172  186.868172  186.868172
# 1                    SNR (Passband 2)  183.836211  183.836211  183.836211
# 2               Attenuation (>4000Hz)   33.044180   46.297756   40.606557
# 3  Leakage (Mid Stopband to Adjacent)   -2.114659  -16.893473   -5.588675
# 4      Leakage (Stopband to Passband)  -31.047476  -43.676646  -38.782895
