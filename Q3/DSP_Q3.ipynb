# %% [markdown]
# #Imports

# %%
# !pip install pyfftw
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 69.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %% [markdown]
# #Section1 & 2

# %% [markdown]
# #Section 3

# %%
# Out:
# L = 50: Direct Convolution Time = 0.002558 s, FFT Convolution Time = 0.001287 s
# L = 1000: Direct Convolution Time = 1.155637 s, FFT Convolution Time = 0.000257 s
