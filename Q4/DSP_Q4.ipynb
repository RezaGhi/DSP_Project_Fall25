# %% [markdown]
# #Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
import scipy.signal as sig

# %% [markdown]
# #Section1

# %% [markdown]
# #Section2 & 3

# %% [markdown]
# #Section4 & 5
