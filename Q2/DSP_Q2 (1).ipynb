# %% [markdown]
# #Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
import cv2

# %% [markdown]
# #Section 1

# %% [markdown]
# #Section2

# %% [markdown]
# #Section3

# %%
# Out:
# True

# %% [markdown]
# #Section4

# %% [markdown]
# Reconstructed Image 1 (reconstructed1.bmp) is more similar to Peppers.bmp because it retains the phase of Peppers.bmp while using the magnitude from Baboon.bmp.\
# Reconstructed Image 2 (reconstructed2.bmp) is more similar to Baboon.bmp because it retains the phase of Baboon.bmp while using the magnitude from Peppers.bmp.\
# This confirms that phase plays a crucial role in perceptual similarity, as it defines the fine details and structure of an image.

# %% [markdown]
# #Section5

# %% [markdown]
# #Section6
